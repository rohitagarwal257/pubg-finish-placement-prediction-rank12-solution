# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import forest, RandomForestRegressor
import lightgbm as lgb
import gc
import feather
import warnings; 
warnings.filterwarnings('ignore')
INPUT_DIR = "../input/"

# %%
#Function to display all
def display_all(df):
    with pd.option_context("display.max_rows", 500, "display.max_columns", 500):
        display(df)

#Function to reduce memory usage
def reduce_mem_usage(df):
    for col in df.columns:
        col_type = df[col].dtype
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    return df

# %%
#Dataframe pre-processing
def dataproc1(df):
    df['playersJoined'] = df.groupby('matchId')['matchId'].transform('count')
    df['headshotrate'] = df['kills']/df['headshotKills']
    df['killStreakrate'] = df['killStreaks']/df['kills']
    df['DBNOs_over_kills'] = df['DBNOs']/df['kills']
    df['healthitems'] = df['heals'] + df['boosts']
    df['heals_over_boosts'] = df['heals'] / df['boosts']
    df['healthitems_norm'] = df['heals']/2.679982 + df['boosts']/1.715794
    df['healthitems_over_kills'] = df['healthitems'] / df['kills']
    df['healthitems_norm_over_kills'] = df['healthitems_norm'] / df['kills']
    df['walkDistance_over_heals'] = df['walkDistance'] / df['heals']
    df['walkDistance_x_heals'] = df['walkDistance'] * df['heals']
    df['walkDistance_over_kills'] = df['walkDistance'] / df['kills']
    df['walkDistance_x_kills'] = df['walkDistance'] * df['kills']
    df['walkDistance_over_healthitems'] = df['walkDistance'] / df['healthitems']
    df['walkDistance_x_healthitems'] = df['walkDistance'] * df['healthitems']
    df["skill"] = df["headshotKills"] + df["roadKills"]
    df['killPlace_over_maxPlace'] = df['killPlace'] / df['maxPlace']
    df['killPlace_over_numGroups'] = df['killPlace'] / df['numGroups']
    df['rideDistance'] = (df['rideDistance']/500)
    df['walkDistance'] = (df['walkDistance']/500)
    df['swimDistance'] = (df['swimDistance']/500)
    df["total_time_by_distance"] = (df["rideDistance"]/4.5+df["walkDistance"]+df["swimDistance"]*1.5)
    df["total_time_by_distance_rank"] = df.groupby('matchId')['total_time_by_distance'].rank(pct=True)
    df["total_time_by_distance_place"] = df['total_time_by_distance_rank'] * df['playersJoined']
    df["total_time_by_distance_perc"] = (df['playersJoined'] - df['total_time_by_distance_place'])/(df['playersJoined'] - 1)
    df['totalDistance'] = df['rideDistance'] + df["walkDistance"] + df["swimDistance"]
    df['distance_over_weapons'] = df['totalDistance'] / df['weaponsAcquired']
    df['distance_x_weapons'] = df['totalDistance'] * df['weaponsAcquired']
    df['total_time_by_distance_over_weapons'] = df['total_time_by_distance'] / df['weaponsAcquired']
    df['total_time_by_distance_x_weapons'] = df['total_time_by_distance'] * df['weaponsAcquired']
    df['killPlace_over_total_time_by_distance'] = df['killPlace'] / df['total_time_by_distance']
    df['killPlace_x_total_time_by_distance'] = df['killPlace'] * df['total_time_by_distance']
    df['killPlace_over_totalDistance'] = df['killPlace'] / df['totalDistance']
    df['killPlace_x_totalDistance'] = df['killPlace'] * df['totalDistance']    
    df['boosts_over_total_time_by_distance'] = df['boosts'] / df['total_time_by_distance']
    df['boosts_x_total_time_by_distance'] = df['boosts'] * df['total_time_by_distance']
    df['boosts_over_totalDistance'] = df['boosts'] / df['totalDistance']
    df['boosts_x_totalDistance'] = df['boosts'] * df['totalDistance']    
    df['teamwork'] = df['assists'] + df['revives'] - df['teamKills']
    df['total_items_acquired'] = (df["boosts"] + df["heals"] + df["weaponsAcquired"])
    df['total_items_acquired_norm'] = (df["boosts"]/1.715794 + df["heals"]/2.679982 + df["weaponsAcquired"]/2.456543)
    df['total_items_acquired_over_total_time_by_distance'] = df['total_items_acquired'] / df['total_time_by_distance']
    df['total_items_acquired_x_total_time_by_distance'] = df['total_items_acquired'] * df['total_time_by_distance']
    df['total_items_acquired_+_total_time_by_distance'] = df['total_items_acquired'] + df['total_time_by_distance']
    df['total_items_acquired_+_total_time_by_distance_norm'] = df['total_items_acquired']/5.346595 + df['total_time_by_distance']/2.661833    
    df['total_items_acquired_norm_over_total_time_by_distance'] = df['total_items_acquired_norm'] / df['total_time_by_distance']
    df['total_items_acquired_norm_x_total_time_by_distance'] = df['total_items_acquired_norm'] * df['total_time_by_distance']
    df['total_items_acquired_norm_+_total_time_by_distance'] = df['total_items_acquired_norm'] + df['total_time_by_distance']
    
    df['total_items_acquired_norm_+_total_time_by_distance_norm'] = df['total_items_acquired_norm']/3.417951 + df['total_time_by_distance']/2.661833

    df['total_items_acquired_x_total_time_by_distance_rank'] = df.groupby('matchId')['total_items_acquired_x_total_time_by_distance'].rank(pct=True)
    df['total_items_acquired_x_total_time_by_distance_place'] = df['total_items_acquired_x_total_time_by_distance_rank'] * df['playersJoined']
    df['total_items_acquired_x_total_time_by_distance_perc'] = (df['playersJoined'] - df['total_items_acquired_x_total_time_by_distance_place']) / (df['playersJoined'] - 1)
    df['heals_over_total_time_by_distance'] = df['heals'] / df['total_time_by_distance']
    df['heals_x_total_time_by_distance'] = df['heals'] * df['total_time_by_distance']    
    df['heals_over_totalDistance'] = df['heals'] / df['totalDistance']
    df['heals_x_totalDistance'] = df['heals'] * df['totalDistance']    
    df['kills_over_total_time_by_distance'] = df['kills'] / df['total_time_by_distance']
    df['kills_x_total_time_by_distance'] = df['kills'] * df['total_time_by_distance']
    df['kills_over_totalDistance'] = df['kills'] / df['totalDistance']
    df['kills_x_totalDistance'] = df['kills'] * df['totalDistance']    
    df['killsNorm'] = df['kills']*((100-df['playersJoined'])/100 + 1)
    df['damageDealtNorm'] = df['damageDealt']*((100-df['playersJoined'])/100 + 1)
    df['maxPlaceNorm'] = df['maxPlace']*((100-df['playersJoined'])/100 + 1)
    df['killPlace_over_maxPlaceNorm'] = df['killPlace'] / df['maxPlaceNorm']
    df['killPlace_over_playersJoined'] = df['killPlace'] / df['playersJoined'] 
    df['killPlace_-_playersJoined'] = df['killPlace'] - df['playersJoined']
    df['killPlace_-_playersJoined_norm'] = df['killPlace']/27.46293 - df['playersJoined']/6.686392
    df['matchDurationNorm'] = df['matchDuration']*((100-df['playersJoined'])/100 + 1)
    df['killPlace_over_matchDuration'] = df['killPlace'] / df['matchDuration']
    df['killPlace_over_matchDurationnorm'] = df['killPlace'] / df['matchDurationNorm'] 
    df['killPlace_-_matchDurationnorm'] = df['killPlace'] - df['matchDurationNorm']
    df['killPlace_-_matchDurationnorm_rank'] = df.groupby('matchId')['killPlace_-_matchDurationnorm'].rank(pct=True)
    df['killPlace_-_matchDurationnorm_place'] = df['killPlace_-_matchDurationnorm_rank'] * df['playersJoined']
    df['killPlace_-_matchDurationnorm_perc'] = (df['playersJoined'] - df['killPlace_-_matchDurationnorm_place']) / (df['playersJoined'] - 1)
    df['killPlace_-_matchDurationnorm_norm'] = df['killPlace']/27.46293 - df['matchDurationNorm']/303.5284
    df['killPlacePerc'] = (df['playersJoined'] - df['killPlace']) / (df['playersJoined'] - 1)
    df['L1'] = df['roadKills'] + df['vehicleDestroys'] + df['teamKills']
    df['L2'] = df['revives'] + df['headshotKills'] + df['assists']
    df['L3'] = df['killStreaks'] + df['DBNOs'] + df['kills'] + df['boosts'] + df['heals']
    df['points'] = df['killPoints']+df['rankPoints'] + df['winPoints']
    df['L1_over_total_time_by_distance'] = df['L1'] / df['total_time_by_distance']
    df['L1_x_total_time_by_distance'] = df['L1'] * df['total_time_by_distance']
    df['L1_over_totalDistance'] = df['L1'] / df['totalDistance']
    df['L1_x_totalDistance'] = df['L1'] * df['totalDistance']    
    df['L2_over_total_time_by_distance'] = df['L2'] / df['total_time_by_distance']
    df['L2_x_total_time_by_distance'] = df['L2'] * df['total_time_by_distance']
    df['L2_over_totalDistance'] = df['L2'] / df['totalDistance']
    df['L2_x_totalDistance'] = df['L2'] * df['totalDistance']    
    df['L3_over_total_time_by_distance'] = df['L3'] / df['total_time_by_distance']
    df['L3_x_total_time_by_distance'] = df['L3'] * df['total_time_by_distance']
    df['L3_over_totalDistance'] = df['L3'] / df['totalDistance']
    df['L3_x_totalDistance'] = df['L3'] * df['totalDistance']
    df['damage1'] = df['damageDealt'] + df['kills'] * 100
    df['damage2'] = df['damageDealt'] + df['kills'] * 100 + df['DBNOs'] * 100
    df[df == np.Inf] = np.NaN
    df[df == np.NINF] = np.NaN
    df.fillna(0, inplace=True)  
    reduce_mem_usage(df)
    return df

#List of features
def dataproc2(df, is_train='TRUE'):
    print("Starting dataproc2")
    features = list(df.columns)
    if is_train=='TRUE':
        features.remove(target)
    features.remove("Id")
    features.remove("matchId")
    features.remove("groupId")
    features.remove("matchType")
    features.remove("numGroups")
    features.remove("playersJoined")
    features.remove("roadKills")
    features.remove("vehicleDestroys")
    features.remove("healthitems")
    features.remove("healthitems_norm")
    features.remove("killPoints")
    features.remove("L1")
    features.remove("L1_over_total_time_by_distance")
    features.remove("L1_x_totalDistance")
    features.remove("matchDurationNorm")
    features.remove("teamKills")
    features.remove("total_items_acquired")
    #imp_cols=['matchId', 'groupId', 'winPlacePerc']
    print("Step 1")
    tmp = df.groupby(['matchId','groupId'])[features].agg('mean')
    df_out = tmp.reset_index()[['matchId','groupId']]
    if is_train=='TRUE':
        tmp3 = df.groupby(['matchId','groupId'])[target].agg('mean')
        df_out = df_out.merge(tmp3.reset_index(), how='left', on=['matchId','groupId'])
        del tmp3
        gc.collect()
    print("Step 2")
    print(df_out.shape)
    reduce_mem_usage(df_out)    
    features.remove("matchDuration")
    tmp2 = tmp.groupby('matchId')[features].rank(pct=True)
    df_out = df_out.merge(tmp.add_suffix('_mean').reset_index(), how='left', on=['matchId', 'groupId'])
    #imp_cols.extend(['boosts_mean','killPlace_mean','kills_mean','longestKill_mean','matchDuration_mean','walkDistance_mean','walkDistance_over_kills_mean','killPlace_over_maxPlace_mean','killPlace_over_numGroups_mean','total_items_acquired_mean','weapons_over_totaltime_mean','killPlace_over_maxPlaceNorm_mean','killPlace_over_maxPlacenorm_mean','killPlacePerc_mean'])
    #df_out = df_out[imp_cols]
    df_out = df_out.merge(tmp2.add_suffix('_mean_rank').reset_index(), how='left', on=['matchId', 'groupId'])
    #imp_cols.extend(['boosts_mean_rank','DBNOs_mean_rank','kills_mean_rank','killStreaks_mean_rank','longestKill_mean_rank','rankPoints_mean_rank','walkDistance_mean_rank','weaponsAcquired_mean_rank','killStreakrate_mean_rank','walkDistance_over_kills_mean_rank','killsPerWalkDistance_mean_rank','total_time_by_distance_mean_rank','total_time_by_distance51_mean_rank','totalDistance_mean_rank','distance_over_weapons_mean_rank','killPlace_over_totalDistance_mean_rank','total_items_acquired_mean_rank','weapons_over_totaltime_mean_rank','kills_over_totaltime_mean_rank','killsNorm_mean_rank','killPlace_over_maxPlacenorm_mean_rank','killPlacePerc_mean_rank'])
    #df_out = df_out[imp_cols]
    del tmp
    del tmp2
    gc.collect()
    print("Step 3")
    print(df_out.shape)
    reduce_mem_usage(df_out)    
    tmp = df.groupby(['matchId','groupId'])[features].agg('median')
    tmp2 = tmp.groupby('matchId')[features].rank(pct=True)
    df_out = df_out.merge(tmp.add_suffix('_median').reset_index(), how='left', on=['matchId', 'groupId'])
    #imp_cols.extend(['longestKill_median','walkDistance_median','walkDistance_over_kills_median','killPlace_over_maxPlace_median','killPlace_over_numGroups_median','distance_over_weapons_median','total_items_acquired_median','weapons_over_totaltime_median','killPlace_over_maxPlacenorm_median','killPlacePerc_median'])
    #df_out = df_out[imp_cols]
    df_out = df_out.merge(tmp2.add_suffix('_median_rank').reset_index(), how='left', on=['matchId', 'groupId'])
    #imp_cols.extend(['assists_median_rank','boosts_median_rank','DBNOs_median_rank','kills_median_rank','killStreaks_median_rank','longestKill_median_rank','rankPoints_median_rank','revives_median_rank','rideDistance_median_rank','swimDistance_median_rank','teamKills_median_rank','walkDistance_median_rank','weaponsAcquired_median_rank','killStreakrate_median_rank','healthitems_median_rank','walkDistance_over_heals_median_rank','walkDistance_over_kills_median_rank','killsPerWalkDistance_median_rank','killPlace_over_maxPlace_median_rank','total_time_by_distance_median_rank','total_time_by_distance51_median_rank','totalDistance_median_rank','distance_over_weapons_median_rank','killPlace_over_totalDistance_median_rank','teamwork_median_rank','total_items_acquired_median_rank','weapons_over_totaltime_median_rank','kills_over_totaltime_median_rank','killsNorm_median_rank','killPlace_over_maxPlaceNorm_median_rank','killPlace_over_maxPlacenorm_median_rank','killPlacePerc_median_rank'])
    #df_out = df_out[imp_cols]
    del tmp
    del tmp2
    gc.collect()
    print("Step 4")
    print(df_out.shape)
    reduce_mem_usage(df_out)    
    tmp = df.groupby(['matchId','groupId'])[features].agg('max')
    tmp2 = tmp.groupby('matchId')[features].rank(pct=True)
    df_out = df_out.merge(tmp.add_suffix('_max').reset_index(), how='left', on=['matchId', 'groupId'])
    #imp_cols.extend(['boosts_max','damageDealt_max','killPlace_max','kills_max','longestKill_max','walkDistance_max','killsPerWalkDistance_max','killPlace_over_maxPlace_max','killPlace_over_numGroups_max','total_time_by_distance_max','total_time_by_distance51_max','distance_over_weapons_max','total_items_acquired_max','weapons_over_totaltime_max','killsNorm_max','damageDealtNorm_max','killPlace_over_maxPlaceNorm_max','killPlace_over_maxPlacenorm_max','killPlacePerc_max'])
    #df_out = df_out[imp_cols]
    df_out = df_out.merge(tmp2.add_suffix('_max_rank').reset_index(), how='left', on=['matchId', 'groupId'])
    #imp_cols.extend(['assists_max_rank','boosts_max_rank','DBNOs_max_rank','killPlace_max_rank','killPoints_max_rank','kills_max_rank','killStreaks_max_rank','longestKill_max_rank','rankPoints_max_rank','walkDistance_max_rank','weaponsAcquired_max_rank','winPoints_max_rank','killStreakrate_max_rank','healthitems_max_rank','walkDistance_over_heals_max_rank','walkDistance_over_kills_max_rank','killsPerWalkDistance_max_rank','killPlace_over_maxPlace_max_rank','killPlace_over_numGroups_max_rank','total_time_by_distance_max_rank','total_time_by_distance51_max_rank','totalDistance_max_rank','distance_over_weapons_max_rank','killPlace_over_total_time_by_distance_max_rank','killPlace_over_total_time_by_distance51_max_rank','killPlace_over_totalDistance_max_rank','total_items_acquired_max_rank','weapons_over_totaltime_max_rank','kills_over_totaltime_max_rank','killsNorm_max_rank','killPlace_over_maxPlaceNorm_max_rank','killPlace_over_maxPlacenorm_max_rank','killPlacePerc_max_rank'])
    #df_out = df_out[imp_cols]
    del tmp
    del tmp2
    gc.collect()
    print("Step 5")
    print(df_out.shape)
    reduce_mem_usage(df_out)    
    tmp = df.groupby(['matchId','groupId'])[features].agg('min')
    tmp2 = tmp.groupby('matchId')[features].rank(pct=True)
    df_out = df_out.merge(tmp.add_suffix('_min').reset_index(), how='left', on=['matchId', 'groupId'])
    #imp_cols.extend(['killPlace_min','kills_min','longestKill_min','walkDistance_min','killStreakrate_min','walkDistance_over_kills_min','killsPerWalkDistance_min','killPlace_over_maxPlace_min','killPlace_over_numGroups_min','distance_over_weapons_min','total_items_acquired_min','weapons_over_totaltime_min','kills_over_totaltime_min','killsNorm_min','damageDealtNorm_min','killPlace_over_maxPlaceNorm_min','killPlace_over_maxPlacenorm_min','killPlacePerc_min'])
    #df_out = df_out[imp_cols]
    df_out = df_out.merge(tmp2.add_suffix('_min_rank').reset_index(), how='left', on=['matchId', 'groupId'])
    #imp_cols.extend(['assists_min_rank','boosts_min_rank','damageDealt_min_rank','DBNOs_min_rank','heals_min_rank','killPoints_min_rank','kills_min_rank','killStreaks_min_rank','longestKill_min_rank','rankPoints_min_rank','revives_min_rank','rideDistance_min_rank','swimDistance_min_rank','teamKills_min_rank','walkDistance_min_rank','weaponsAcquired_min_rank','winPoints_min_rank','headshotrate_min_rank','killStreakrate_min_rank','healthitems_min_rank','walkDistance_over_heals_min_rank','walkDistance_over_kills_min_rank','killsPerWalkDistance_min_rank','total_time_by_distance_min_rank','total_time_by_distance51_min_rank','totalDistance_min_rank','distance_over_weapons_min_rank','killPlace_over_total_time_by_distance_min_rank','killPlace_over_total_time_by_distance51_min_rank','killPlace_over_totalDistance_min_rank','teamwork_min_rank','total_items_acquired_min_rank','weapons_over_totaltime_min_rank','heals_over_totaltime_min_rank','kills_over_totaltime_min_rank','killsNorm_min_rank','damageDealtNorm_min_rank','killPlace_over_maxPlaceNorm_min_rank','killPlace_over_maxPlacenorm_min_rank','killPlacePerc_min_rank'])
    #df_out = df_out[imp_cols]
    del tmp
    del tmp2
    gc.collect()
    print("Step 6")
    print(df_out.shape)
    reduce_mem_usage(df_out)    
    tmp = df.groupby(['matchId'])[features].agg('mean')
    df_out = df_out.merge(tmp.add_suffix('_match_mean').reset_index(), how='left', on=['matchId'])   
    #imp_cols.extend(['assists_match_mean','boosts_match_mean','damageDealt_match_mean','DBNOs_match_mean','headshotKills_match_mean','heals_match_mean','kills_match_mean','killStreaks_match_mean','longestKill_match_mean','rankPoints_match_mean','revives_match_mean','rideDistance_match_mean','swimDistance_match_mean','teamKills_match_mean','walkDistance_match_mean','weaponsAcquired_match_mean','headshotrate_match_mean','killStreakrate_match_mean','healthitems_match_mean','walkDistance_over_heals_match_mean','walkDistance_over_kills_match_mean','killsPerWalkDistance_match_mean','skill_match_mean','headshotKills_over_kills_match_mean','distance_over_weapons_match_mean','killPlace_over_total_time_by_distance_match_mean','killPlace_over_total_time_by_distance51_match_mean','killPlace_over_totalDistance_match_mean','teamwork_match_mean','total_items_acquired_match_mean','weapons_over_totaltime_match_mean','heals_over_totaltime_match_mean','kills_over_totaltime_match_mean','killsNorm_match_mean','damageDealtNorm_match_mean'])
    #df_out = df_out[imp_cols]
    del tmp
    gc.collect()
    tmp = df.groupby(['matchId'])[features].agg('median')
    df_out = df_out.merge(tmp.add_suffix('_match_median').reset_index(), how='left', on=['matchId'])   
    #imp_cols.extend(['damageDealt_match_median','walkDistance_match_median','killStreakrate_match_median','totalDistance_match_median','distance_over_weapons_match_median','killPlace_over_total_time_by_distance_match_median','killPlace_over_total_time_by_distance51_match_median','killPlace_over_totalDistance_match_median','weapons_over_totaltime_match_median','kills_over_totaltime_match_median','damageDealtNorm_match_median'])
    #df_out = df_out[imp_cols]
    del tmp
    gc.collect()
    tmp = df.groupby(['matchId'])[features].agg('max')
    df_out = df_out.merge(tmp.add_suffix('_match_max').reset_index(), how='left', on=['matchId'])   
    #imp_cols.extend(['boosts_match_max','damageDealt_match_max','heals_match_max','longestKill_match_max','rankPoints_match_max','rideDistance_match_max','swimDistance_match_max','walkDistance_match_max','weaponsAcquired_match_max','headshotrate_match_max','healthitems_match_max','walkDistance_over_heals_match_max','walkDistance_over_kills_match_max','killsPerWalkDistance_match_max','total_time_by_distance_match_max','total_time_by_distance51_match_max','totalDistance_match_max','distance_over_weapons_match_max','killPlace_over_total_time_by_distance_match_max','killPlace_over_total_time_by_distance51_match_max','killPlace_over_totalDistance_match_max','total_items_acquired_match_max','weapons_over_totaltime_match_max','heals_over_totaltime_match_max','kills_over_totaltime_match_max','killsNorm_match_max','damageDealtNorm_match_max'])
    #df_out = df_out[imp_cols]
    del tmp
    gc.collect()
    print("Step 7")
    print(df_out.shape)
    reduce_mem_usage(df_out)
    tmp = df.groupby(['matchId','groupId'])[features].agg('sum')
    tmp2 = tmp.groupby('matchId')[features].rank(pct=True)
    df_out = df_out.merge(tmp.add_suffix('_sum').reset_index(), how='left', on=['matchId', 'groupId'])
    del tmp
    gc.collect()
    print(df_out.shape)
    #imp_cols.extend(['damageDealt_sum','longestKill_sum','rankPoints_sum','walkDistance_sum','walkDistance_over_kills_sum','killsPerWalkDistance_sum','killPlace_over_maxPlace_sum','killPlace_over_numGroups_sum','distance_over_weapons_sum','weapons_over_totaltime_sum','kills_over_totaltime_sum','killsNorm_sum','damageDealtNorm_sum','maxPlaceNorm_sum','matchDurationNorm_sum','killPlace_over_maxPlacenorm_sum','killPlacePerc_sum'])
    #df_out = df_out[imp_cols]
    df_out = df_out.merge(tmp2.add_suffix('_sum_rank').reset_index(), how='left', on=['matchId', 'groupId'])
    print(df_out.shape)
    #imp_cols.extend(['assists_sum_rank','boosts_sum_rank','DBNOs_sum_rank','killPoints_sum_rank','kills_sum_rank','killStreaks_sum_rank','longestKill_sum_rank','rankPoints_sum_rank','walkDistance_sum_rank','weaponsAcquired_sum_rank','winPoints_sum_rank','killStreakrate_sum_rank','healthitems_sum_rank','walkDistance_over_heals_sum_rank','walkDistance_over_kills_sum_rank','killPlace_over_numGroups_sum_rank','total_time_by_distance_sum_rank','total_time_by_distance51_sum_rank','totalDistance_sum_rank','distance_over_weapons_sum_rank','killPlace_over_total_time_by_distance_sum_rank','killPlace_over_totalDistance_sum_rank','teamwork_sum_rank','total_items_acquired_sum_rank','weapons_over_totaltime_sum_rank','kills_over_totaltime_sum_rank','killsNorm_sum_rank','killPlacePerc_sum_rank'])
    #df_out = df_out[imp_cols]
    del tmp2
    gc.collect()
    print("Step 8")
    reduce_mem_usage(df_out)    
    print(df_out.shape)
    df_out = df_out.assign(agg_group_size=df.groupby('groupId').groupId.transform('count'))
    print(df_out.shape)
    df_out = df_out.assign(agg_match_size=df.groupby('matchId').Id.transform('nunique'))
    print(df_out.shape)
    print("Step 9")
    del df_out["matchId"]
    del df_out["groupId"]
    reduce_mem_usage(df_out)
    gc.collect()
    return df_out

# %%
# %%time
df = pd.read_csv(INPUT_DIR + 'train_V2.csv')
df = df[df['maxPlace'] > 1]
reduce_mem_usage(df)
target = 'winPlacePerc'
df = dataproc1(df)
df.reset_index().to_feather('tmp/20190109_df')
df_out = dataproc2(df)
del df
gc.collect()
df_out.to_feather('tmp/20190109_df_out')
y_train = df_out[target]
x_train = df_out.drop(target, axis=1)
del df_out
gc.collect()
# Out:
# Starting dataproc2
# Step 1
# Step 2
# (2026744, 3)
# Step 3
# (2026744, 206)
# Step 4
# (2026744, 408)
# Step 5
# (2026744, 610)
# Step 6
# (2026744, 812)
# Step 7
# (2026744, 1115)
# (2026744, 1216)
# (2026744, 1317)
# Step 8
# (2026744, 1317)
# (2026744, 1318)
# (2026744, 1319)
# Step 9
# CPU times: user 41min 21s, sys: 14min 59s, total: 56min 20s
# Wall time: 26min 29s

# %%
#df = feather.read_dataframe('tmp/20190109_df')
#target = 'winPlacePerc'
#y_train = df_out[target]
#x_train = df_out.drop(target, axis=1)
#del df_out
#gc.collect()

# %%
m0 = RandomForestRegressor(n_jobs=-1, n_estimators=1, bootstrap=False, verbose=True, max_depth=3, scoring="roc_auc")
# %time m0.fit(x_train, y_train)
print(mean_absolute_error(m0.predict(x_train), y_train))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c512b9a4d44> in <module>
# ----> 1 m0 = RandomForestRegressor(n_jobs=-1, n_estimators=1, bootstrap=False, verbose=True, max_depth=3, scoring="roc_auc")
#       2 get_ipython().run_line_magic('time', 'm0.fit(x_train, y_train)')
#       3 print(mean_absolute_error(m0.predict(x_train), y_train))
#
# NameError: name 'RandomForestRegressor' is not defined

# %%
def dectree_max_depth(tree):
    children_left = tree.children_left
    children_right = tree.children_right

    def walk(node_id):
        if (children_left[node_id] != children_right[node_id]):
            left_max = 1 + walk(children_left[node_id])
            right_max = 1 + walk(children_right[node_id])
            return max(left_max, right_max)
        else: # leaf
            return 1

    root_node_id = 0
    return walk(root_node_id)

t=m0.estimators_[0].tree_
dectree_max_depth(t)
# Out:
# 4

# %%
def rf_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}
                       ).sort_values('imp', ascending=False)
fi = rf_feat_importance(m0, x_train); display_all(fi)
fi.to_csv("tmp/20190109_fi_2.csv")
col = pd.Series(x_train.columns)
col.to_csv("tmp/20190109_col_2.csv")
fi_imp=fi[:359]
fi_imp.to_csv("tmp/20190109_fi_imp_2.csv")
# Out:
#                                                    cols       imp
# 159   total_items_acquired_norm_x_total_time_by_dist...  0.793644
# 512                                  killPlace_max_rank  0.090806
# 565   total_items_acquired_norm_+_total_time_by_dist...  0.083481
# 346   killPlace_over_total_time_by_distance_median_rank  0.011606
# 539                     total_time_by_distance_max_rank  0.011082
# 581               killPlace_over_playersJoined_max_rank  0.009381
# 0                                          assists_mean  0.000000
# 875                    heals_x_totalDistance_match_mean  0.000000
# 881                          damageDealtNorm_match_mean  0.000000
# 880                                killsNorm_match_mean  0.000000
# 879                    kills_x_totalDistance_match_mean  0.000000
# 878                 kills_over_totalDistance_match_mean  0.000000
# 877           kills_x_total_time_by_distance_match_mean  0.000000
# 876        kills_over_total_time_by_distance_match_mean  0.000000
# 874                 heals_over_totalDistance_match_mean  0.000000
# 883              killPlace_over_maxPlaceNorm_match_mean  0.000000
# 873           heals_x_total_time_by_distance_match_mean  0.000000
# 872        heals_over_total_time_by_distance_match_mean  0.000000
# 871   total_items_acquired_x_total_time_by_distance_...  0.000000
# 870   total_items_acquired_x_total_time_by_distance_...  0.000000
# 869   total_items_acquired_x_total_time_by_distance_...  0.000000
# 868   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 867   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 882                             maxPlaceNorm_match_mean  0.000000
# 886           killPlace_-_playersJoined_norm_match_mean  0.000000
# 884             killPlace_over_playersJoined_match_mean  0.000000
# 894                            killPlacePerc_match_mean  0.000000
# 901              L2_x_total_time_by_distance_match_mean  0.000000
# 900           L2_over_total_time_by_distance_match_mean  0.000000
# 899                    L1_over_totalDistance_match_mean  0.000000
# 898              L1_x_total_time_by_distance_match_mean  0.000000
# 897                                   points_match_mean  0.000000
# 896                                       L3_match_mean  0.000000
# 895                                       L2_match_mean  0.000000
# 893       killPlace_-_matchDurationnorm_norm_match_mean  0.000000
# 885                killPlace_-_playersJoined_match_mean  0.000000
# 892       killPlace_-_matchDurationnorm_perc_match_mean  0.000000
# 891      killPlace_-_matchDurationnorm_place_match_mean  0.000000
# 890       killPlace_-_matchDurationnorm_rank_match_mean  0.000000
# 889            killPlace_-_matchDurationnorm_match_mean  0.000000
# 888         killPlace_over_matchDurationnorm_match_mean  0.000000
# 887             killPlace_over_matchDuration_match_mean  0.000000
# 865   total_items_acquired_norm_over_total_time_by_d...  0.000000
# 866   total_items_acquired_norm_x_total_time_by_dist...  0.000000
# 863   total_items_acquired_+_total_time_by_distance_...  0.000000
# 864   total_items_acquired_+_total_time_by_distance_...  0.000000
# 903                       L2_x_totalDistance_match_mean  0.000000
# 842                   total_time_by_distance_match_mean  0.000000
# 841                 killPlace_over_numGroups_match_mean  0.000000
# 840                  killPlace_over_maxPlace_match_mean  0.000000
# 839                                    skill_match_mean  0.000000
# 838               walkDistance_x_healthitems_match_mean  0.000000
# 837            walkDistance_over_healthitems_match_mean  0.000000
# 836                     walkDistance_x_kills_match_mean  0.000000
# 835                  walkDistance_over_kills_match_mean  0.000000
# 834                     walkDistance_x_heals_match_mean  0.000000
# 833                  walkDistance_over_heals_match_mean  0.000000
# 832              healthitems_norm_over_kills_match_mean  0.000000
# 831                   healthitems_over_kills_match_mean  0.000000
# 830                        heals_over_boosts_match_mean  0.000000
# 829                         DBNOs_over_kills_match_mean  0.000000
# 828                           killStreakrate_match_mean  0.000000
# 827                             headshotrate_match_mean  0.000000
# 826                                winPoints_match_mean  0.000000
# 843              total_time_by_distance_rank_match_mean  0.000000
# 844             total_time_by_distance_place_match_mean  0.000000
# 845              total_time_by_distance_perc_match_mean  0.000000
# 855       boosts_over_total_time_by_distance_match_mean  0.000000
# 862   total_items_acquired_x_total_time_by_distance_...  0.000000
# 861   total_items_acquired_over_total_time_by_distan...  0.000000
# 860                total_items_acquired_norm_match_mean  0.000000
# 859                                 teamwork_match_mean  0.000000
# 858                   boosts_x_totalDistance_match_mean  0.000000
# 857                boosts_over_totalDistance_match_mean  0.000000
# 856          boosts_x_total_time_by_distance_match_mean  0.000000
# 854                killPlace_x_totalDistance_match_mean  0.000000
# 846                            totalDistance_match_mean  0.000000
# 853             killPlace_over_totalDistance_match_mean  0.000000
# 852       killPlace_x_total_time_by_distance_match_mean  0.000000
# 851    killPlace_over_total_time_by_distance_match_mean  0.000000
# 850         total_time_by_distance_x_weapons_match_mean  0.000000
# 849      total_time_by_distance_over_weapons_match_mean  0.000000
# 848                       distance_x_weapons_match_mean  0.000000
# 847                    distance_over_weapons_match_mean  0.000000
# 902                    L2_over_totalDistance_match_mean  0.000000
# 904           L3_over_total_time_by_distance_match_mean  0.000000
# 824                             walkDistance_match_mean  0.000000
# 965   total_items_acquired_+_total_time_by_distance_...  0.000000
# 963   total_items_acquired_x_total_time_by_distance_...  0.000000
# 962   total_items_acquired_over_total_time_by_distan...  0.000000
# 961              total_items_acquired_norm_match_median  0.000000
# 960                               teamwork_match_median  0.000000
# 959                 boosts_x_totalDistance_match_median  0.000000
# 958              boosts_over_totalDistance_match_median  0.000000
# 957        boosts_x_total_time_by_distance_match_median  0.000000
# 956     boosts_over_total_time_by_distance_match_median  0.000000
# 955              killPlace_x_totalDistance_match_median  0.000000
# 954           killPlace_over_totalDistance_match_median  0.000000
# 953     killPlace_x_total_time_by_distance_match_median  0.000000
# 952   killPlace_over_total_time_by_distance_match_me...  0.000000
# 951       total_time_by_distance_x_weapons_match_median  0.000000
# 950    total_time_by_distance_over_weapons_match_median  0.000000
# 949                     distance_x_weapons_match_median  0.000000
# 948                  distance_over_weapons_match_median  0.000000
# 947                          totalDistance_match_median  0.000000
# 964   total_items_acquired_+_total_time_by_distance_...  0.000000
# 966   total_items_acquired_norm_over_total_time_by_d...  0.000000
# 905              L3_x_total_time_by_distance_match_mean  0.000000
# 967   total_items_acquired_norm_x_total_time_by_dist...  0.000000
# 984            killPlace_over_maxPlaceNorm_match_median  0.000000
# 983                           maxPlaceNorm_match_median  0.000000
# 982                        damageDealtNorm_match_median  0.000000
# 981                              killsNorm_match_median  0.000000
# 980                  kills_x_totalDistance_match_median  0.000000
# 979               kills_over_totalDistance_match_median  0.000000
# 978         kills_x_total_time_by_distance_match_median  0.000000
# 977      kills_over_total_time_by_distance_match_median  0.000000
# 976                  heals_x_totalDistance_match_median  0.000000
# 975               heals_over_totalDistance_match_median  0.000000
# 974         heals_x_total_time_by_distance_match_median  0.000000
# 973      heals_over_total_time_by_distance_match_median  0.000000
# 972   total_items_acquired_x_total_time_by_distance_...  0.000000
# 971   total_items_acquired_x_total_time_by_distance_...  0.000000
# 970   total_items_acquired_x_total_time_by_distance_...  0.000000
# 969   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 968   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 946            total_time_by_distance_perc_match_median  0.000000
# 945           total_time_by_distance_place_match_median  0.000000
# 944            total_time_by_distance_rank_match_median  0.000000
# 943                 total_time_by_distance_match_median  0.000000
# 922                                revives_match_median  0.000000
# 921                             rankPoints_match_median  0.000000
# 920                               maxPlace_match_median  0.000000
# 919                            longestKill_match_median  0.000000
# 918                            killStreaks_match_median  0.000000
# 917                                  kills_match_median  0.000000
# 916                              killPlace_match_median  0.000000
# 915                                  heals_match_median  0.000000
# 914                          headshotKills_match_median  0.000000
# 913                                  DBNOs_match_median  0.000000
# 912                            damageDealt_match_median  0.000000
# 911                                 boosts_match_median  0.000000
# 910                                assists_match_median  0.000000
# 909                                  damage2_match_mean  0.000000
# 908                                  damage1_match_mean  0.000000
# 907                       L3_x_totalDistance_match_mean  0.000000
# 906                    L3_over_totalDistance_match_mean  0.000000
# 923                           rideDistance_match_median  0.000000
# 924                           swimDistance_match_median  0.000000
# 925                           walkDistance_match_median  0.000000
# 935                   walkDistance_x_heals_match_median  0.000000
# 942               killPlace_over_numGroups_match_median  0.000000
# 941                killPlace_over_maxPlace_match_median  0.000000
# 940                                  skill_match_median  0.000000
# 939             walkDistance_x_healthitems_match_median  0.000000
# 938          walkDistance_over_healthitems_match_median  0.000000
# 937                   walkDistance_x_kills_match_median  0.000000
# 936                walkDistance_over_kills_match_median  0.000000
# 934                walkDistance_over_heals_match_median  0.000000
# 926                        weaponsAcquired_match_median  0.000000
# 933            healthitems_norm_over_kills_match_median  0.000000
# 932                 healthitems_over_kills_match_median  0.000000
# 931                      heals_over_boosts_match_median  0.000000
# 930                       DBNOs_over_kills_match_median  0.000000
# 929                         killStreakrate_match_median  0.000000
# 928                           headshotrate_match_median  0.000000
# 927                              winPoints_match_median  0.000000
# 825                          weaponsAcquired_match_mean  0.000000
# 821                                  revives_match_mean  0.000000
# 823                             swimDistance_match_mean  0.000000
# 702                  L3_over_total_time_by_distance_min  0.000000
# 720                                    revives_min_rank  0.000000
# 719                                 rankPoints_min_rank  0.000000
# 718                                   maxPlace_min_rank  0.000000
# 717                                longestKill_min_rank  0.000000
# 716                                killStreaks_min_rank  0.000000
# 715                                      kills_min_rank  0.000000
# 714                                  killPlace_min_rank  0.000000
# 713                                      heals_min_rank  0.000000
# 712                              headshotKills_min_rank  0.000000
# 711                                      DBNOs_min_rank  0.000000
# 710                                damageDealt_min_rank  0.000000
# 709                                     boosts_min_rank  0.000000
# 708                                    assists_min_rank  0.000000
# 707                                         damage2_min  0.000000
# 706                                         damage1_min  0.000000
# 705                              L3_x_totalDistance_min  0.000000
# 704                           L3_over_totalDistance_min  0.000000
# 721                               rideDistance_min_rank  0.000000
# 722                               swimDistance_min_rank  0.000000
# 723                               walkDistance_min_rank  0.000000
# 733                       walkDistance_x_heals_min_rank  0.000000
# 740                   killPlace_over_numGroups_min_rank  0.000000
# 739                    killPlace_over_maxPlace_min_rank  0.000000
# 738                                      skill_min_rank  0.000000
# 737                 walkDistance_x_healthitems_min_rank  0.000000
# 736              walkDistance_over_healthitems_min_rank  0.000000
# 735                       walkDistance_x_kills_min_rank  0.000000
# 734                    walkDistance_over_kills_min_rank  0.000000
# 732                    walkDistance_over_heals_min_rank  0.000000
# 724                            weaponsAcquired_min_rank  0.000000
# 731                healthitems_norm_over_kills_min_rank  0.000000
# 730                     healthitems_over_kills_min_rank  0.000000
# 729                          heals_over_boosts_min_rank  0.000000
# 728                           DBNOs_over_kills_min_rank  0.000000
# 727                             killStreakrate_min_rank  0.000000
# 726                               headshotrate_min_rank  0.000000
# 725                                  winPoints_min_rank  0.000000
# 703                     L3_x_total_time_by_distance_min  0.000000
# 701                              L2_x_totalDistance_min  0.000000
# 822                             rideDistance_match_mean  0.000000
# 700                           L2_over_totalDistance_min  0.000000
# 679                                 damageDealtNorm_min  0.000000
# 678                                       killsNorm_min  0.000000
# 677                           kills_x_totalDistance_min  0.000000
# 676                        kills_over_totalDistance_min  0.000000
# 675                  kills_x_total_time_by_distance_min  0.000000
# 674               kills_over_total_time_by_distance_min  0.000000
# 673                           heals_x_totalDistance_min  0.000000
# 672                        heals_over_totalDistance_min  0.000000
# 671                  heals_x_total_time_by_distance_min  0.000000
# 670               heals_over_total_time_by_distance_min  0.000000
# 669   total_items_acquired_x_total_time_by_distance_...  0.000000
# 668   total_items_acquired_x_total_time_by_distance_...  0.000000
# 667   total_items_acquired_x_total_time_by_distance_...  0.000000
# 666   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 665   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 664   total_items_acquired_norm_x_total_time_by_dist...  0.000000
# 663   total_items_acquired_norm_over_total_time_by_d...  0.000000
# 680                                    maxPlaceNorm_min  0.000000
# 681                     killPlace_over_maxPlaceNorm_min  0.000000
# 682                    killPlace_over_playersJoined_min  0.000000
# 692                                   killPlacePerc_min  0.000000
# 699                     L2_x_total_time_by_distance_min  0.000000
# 698                  L2_over_total_time_by_distance_min  0.000000
# 697                           L1_over_totalDistance_min  0.000000
# 696                     L1_x_total_time_by_distance_min  0.000000
# 695                                          points_min  0.000000
# 694                                              L3_min  0.000000
# 693                                              L2_min  0.000000
# 691              killPlace_-_matchDurationnorm_norm_min  0.000000
# 683                       killPlace_-_playersJoined_min  0.000000
# 690              killPlace_-_matchDurationnorm_perc_min  0.000000
# 689             killPlace_-_matchDurationnorm_place_min  0.000000
# 688              killPlace_-_matchDurationnorm_rank_min  0.000000
# 687                   killPlace_-_matchDurationnorm_min  0.000000
# 686                killPlace_over_matchDurationnorm_min  0.000000
# 685                    killPlace_over_matchDuration_min  0.000000
# 684                  killPlace_-_playersJoined_norm_min  0.000000
# 741                     total_time_by_distance_min_rank  0.000000
# ...                                                 ...       ...
# 520                               swimDistance_max_rank  0.000000
# 519                               rideDistance_max_rank  0.000000
# 518                                    revives_max_rank  0.000000
# 517                                 rankPoints_max_rank  0.000000
# 576                      kills_x_totalDistance_max_rank  0.000000
# 578                            damageDealtNorm_max_rank  0.000000
# 330                 walkDistance_over_kills_median_rank  0.000000
# 620                                    rideDistance_min  0.000000
# 638                         killPlace_over_maxPlace_min  0.000000
# 637                                           skill_min  0.000000
# 636                      walkDistance_x_healthitems_min  0.000000
# 635                   walkDistance_over_healthitems_min  0.000000
# 634                            walkDistance_x_kills_min  0.000000
# 633                         walkDistance_over_kills_min  0.000000
# 632                            walkDistance_x_heals_min  0.000000
# 631                         walkDistance_over_heals_min  0.000000
# 630                     healthitems_norm_over_kills_min  0.000000
# 629                          healthitems_over_kills_min  0.000000
# 628                               heals_over_boosts_min  0.000000
# 627                                DBNOs_over_kills_min  0.000000
# 626                                  killStreakrate_min  0.000000
# 625                                    headshotrate_min  0.000000
# 624                                       winPoints_min  0.000000
# 623                                 weaponsAcquired_min  0.000000
# 622                                    walkDistance_min  0.000000
# 639                        killPlace_over_numGroups_min  0.000000
# 640                          total_time_by_distance_min  0.000000
# 641                     total_time_by_distance_rank_min  0.000000
# 651                    killPlace_over_totalDistance_min  0.000000
# 1                                           boosts_mean  0.000000
# 657                                        teamwork_min  0.000000
# 656                          boosts_x_totalDistance_min  0.000000
# 655                       boosts_over_totalDistance_min  0.000000
# 654                 boosts_x_total_time_by_distance_min  0.000000
# 653              boosts_over_total_time_by_distance_min  0.000000
# 652                       killPlace_x_totalDistance_min  0.000000
# 650              killPlace_x_total_time_by_distance_min  0.000000
# 642                    total_time_by_distance_place_min  0.000000
# 649           killPlace_over_total_time_by_distance_min  0.000000
# 648                total_time_by_distance_x_weapons_min  0.000000
# 647             total_time_by_distance_over_weapons_min  0.000000
# 646                              distance_x_weapons_min  0.000000
# 645                           distance_over_weapons_min  0.000000
# 644                                   totalDistance_min  0.000000
# 643                     total_time_by_distance_perc_min  0.000000
# 621                                    swimDistance_min  0.000000
# 619                                         revives_min  0.000000
# 579                               maxPlaceNorm_max_rank  0.000000
# 618                                      rankPoints_min  0.000000
# 597             L2_over_total_time_by_distance_max_rank  0.000000
# 596                      L1_over_totalDistance_max_rank  0.000000
# 595                L1_x_total_time_by_distance_max_rank  0.000000
# 594                                     points_max_rank  0.000000
# 593                                         L3_max_rank  0.000000
# 592                                         L2_max_rank  0.000000
# 591                              killPlacePerc_max_rank  0.000000
# 590         killPlace_-_matchDurationnorm_norm_max_rank  0.000000
# 589         killPlace_-_matchDurationnorm_perc_max_rank  0.000000
# 588        killPlace_-_matchDurationnorm_place_max_rank  0.000000
# 587         killPlace_-_matchDurationnorm_rank_max_rank  0.000000
# 586              killPlace_-_matchDurationnorm_max_rank  0.000000
# 585           killPlace_over_matchDurationnorm_max_rank  0.000000
# 584               killPlace_over_matchDuration_max_rank  0.000000
# 583             killPlace_-_playersJoined_norm_max_rank  0.000000
# 582                  killPlace_-_playersJoined_max_rank  0.000000
# 580                killPlace_over_maxPlaceNorm_max_rank  0.000000
# 598                L2_x_total_time_by_distance_max_rank  0.000000
# 599                      L2_over_totalDistance_max_rank  0.000000
# 600                         L2_x_totalDistance_max_rank  0.000000
# 610                                           DBNOs_min  0.000000
# 617                                        maxPlace_min  0.000000
# 616                                     longestKill_min  0.000000
# 615                                     killStreaks_min  0.000000
# 614                                           kills_min  0.000000
# 613                                       killPlace_min  0.000000
# 612                                           heals_min  0.000000
# 611                                   headshotKills_min  0.000000
# 609                                     damageDealt_min  0.000000
# 601             L3_over_total_time_by_distance_max_rank  0.000000
# 608                                          boosts_min  0.000000
# 607                                         assists_min  0.000000
# 606                                    damage2_max_rank  0.000000
# 605                                    damage1_max_rank  0.000000
# 604                         L3_x_totalDistance_max_rank  0.000000
# 603                      L3_over_totalDistance_max_rank  0.000000
# 602                L3_x_total_time_by_distance_max_rank  0.000000
# 494                     L1_x_total_time_by_distance_max  0.000000
# 493                                          points_max  0.000000
# 492                                              L3_max  0.000000
# 371       kills_over_total_time_by_distance_median_rank  0.000000
# 389                           killPlacePerc_median_rank  0.000000
# 388      killPlace_-_matchDurationnorm_norm_median_rank  0.000000
# 387      killPlace_-_matchDurationnorm_perc_median_rank  0.000000
# 386     killPlace_-_matchDurationnorm_place_median_rank  0.000000
# 385      killPlace_-_matchDurationnorm_rank_median_rank  0.000000
# 384           killPlace_-_matchDurationnorm_median_rank  0.000000
# 383        killPlace_over_matchDurationnorm_median_rank  0.000000
# 382            killPlace_over_matchDuration_median_rank  0.000000
# 381          killPlace_-_playersJoined_norm_median_rank  0.000000
# 380               killPlace_-_playersJoined_median_rank  0.000000
# 379            killPlace_over_playersJoined_median_rank  0.000000
# 378             killPlace_over_maxPlaceNorm_median_rank  0.000000
# 377                            maxPlaceNorm_median_rank  0.000000
# 376                         damageDealtNorm_median_rank  0.000000
# 375                               killsNorm_median_rank  0.000000
# 374                   kills_x_totalDistance_median_rank  0.000000
# 373                kills_over_totalDistance_median_rank  0.000000
# 390                                      L2_median_rank  0.000000
# 391                                      L3_median_rank  0.000000
# 392                                  points_median_rank  0.000000
# 402                      L3_x_totalDistance_median_rank  0.000000
# 409                                   headshotKills_max  0.000000
# 408                                           DBNOs_max  0.000000
# 407                                     damageDealt_max  0.000000
# 406                                          boosts_max  0.000000
# 405                                         assists_max  0.000000
# 404                                 damage2_median_rank  0.000000
# 403                                 damage1_median_rank  0.000000
# 401                   L3_over_totalDistance_median_rank  0.000000
# 393             L1_x_total_time_by_distance_median_rank  0.000000
# 400             L3_x_total_time_by_distance_median_rank  0.000000
# 399          L3_over_total_time_by_distance_median_rank  0.000000
# 398                      L2_x_totalDistance_median_rank  0.000000
# 397                   L2_over_totalDistance_median_rank  0.000000
# 396             L2_x_total_time_by_distance_median_rank  0.000000
# 395          L2_over_total_time_by_distance_median_rank  0.000000
# 394                   L1_over_totalDistance_median_rank  0.000000
# 372          kills_x_total_time_by_distance_median_rank  0.000000
# 370                   heals_x_totalDistance_median_rank  0.000000
# 491                                              L2_max  0.000000
# 369                heals_over_totalDistance_median_rank  0.000000
# 348            killPlace_over_totalDistance_median_rank  0.000000
# 347      killPlace_x_total_time_by_distance_median_rank  0.000000
# 345        total_time_by_distance_x_weapons_median_rank  0.000000
# 344     total_time_by_distance_over_weapons_median_rank  0.000000
# 343                      distance_x_weapons_median_rank  0.000000
# 342                   distance_over_weapons_median_rank  0.000000
# 341                           totalDistance_median_rank  0.000000
# 340             total_time_by_distance_perc_median_rank  0.000000
# 339            total_time_by_distance_place_median_rank  0.000000
# 338             total_time_by_distance_rank_median_rank  0.000000
# 337                  total_time_by_distance_median_rank  0.000000
# 336                killPlace_over_numGroups_median_rank  0.000000
# 335                 killPlace_over_maxPlace_median_rank  0.000000
# 334                                   skill_median_rank  0.000000
# 333              walkDistance_x_healthitems_median_rank  0.000000
# 332           walkDistance_over_healthitems_median_rank  0.000000
# 331                    walkDistance_x_kills_median_rank  0.000000
# 349               killPlace_x_totalDistance_median_rank  0.000000
# 350      boosts_over_total_time_by_distance_median_rank  0.000000
# 351         boosts_x_total_time_by_distance_median_rank  0.000000
# 361   total_items_acquired_norm_x_total_time_by_dist...  0.000000
# 368          heals_x_total_time_by_distance_median_rank  0.000000
# 367       heals_over_total_time_by_distance_median_rank  0.000000
# 366   total_items_acquired_x_total_time_by_distance_...  0.000000
# 365   total_items_acquired_x_total_time_by_distance_...  0.000000
# 364   total_items_acquired_x_total_time_by_distance_...  0.000000
# 363   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 362   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 360   total_items_acquired_norm_over_total_time_by_d...  0.000000
# 352               boosts_over_totalDistance_median_rank  0.000000
# 359   total_items_acquired_+_total_time_by_distance_...  0.000000
# 358   total_items_acquired_+_total_time_by_distance_...  0.000000
# 357   total_items_acquired_x_total_time_by_distance_...  0.000000
# 356   total_items_acquired_over_total_time_by_distan...  0.000000
# 355               total_items_acquired_norm_median_rank  0.000000
# 354                                teamwork_median_rank  0.000000
# 353                  boosts_x_totalDistance_median_rank  0.000000
# 410                                           heals_max  0.000000
# 411                                       killPlace_max  0.000000
# 412                                           kills_max  0.000000
# 413                                     killStreaks_max  0.000000
# 470                        heals_over_totalDistance_max  0.000000
# 469                  heals_x_total_time_by_distance_max  0.000000
# 468               heals_over_total_time_by_distance_max  0.000000
# 467   total_items_acquired_x_total_time_by_distance_...  0.000000
# 466   total_items_acquired_x_total_time_by_distance_...  0.000000
# 465   total_items_acquired_x_total_time_by_distance_...  0.000000
# 464   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 463   total_items_acquired_norm_+_total_time_by_dist...  0.000000
# 462   total_items_acquired_norm_x_total_time_by_dist...  0.000000
# 461   total_items_acquired_norm_over_total_time_by_d...  0.000000
# 460   total_items_acquired_+_total_time_by_distance_...  0.000000
# 459   total_items_acquired_+_total_time_by_distance_max  0.000000
# 458   total_items_acquired_x_total_time_by_distance_max  0.000000
# 457   total_items_acquired_over_total_time_by_distan...  0.000000
# 456                       total_items_acquired_norm_max  0.000000
# 455                                        teamwork_max  0.000000
# 454                          boosts_x_totalDistance_max  0.000000
# 471                           heals_x_totalDistance_max  0.000000
# 472               kills_over_total_time_by_distance_max  0.000000
# 473                  kills_x_total_time_by_distance_max  0.000000
# 483                    killPlace_over_matchDuration_max  0.000000
# 490                                   killPlacePerc_max  0.000000
# 489              killPlace_-_matchDurationnorm_norm_max  0.000000
# 488              killPlace_-_matchDurationnorm_perc_max  0.000000
# 487             killPlace_-_matchDurationnorm_place_max  0.000000
# 486              killPlace_-_matchDurationnorm_rank_max  0.000000
# 485                   killPlace_-_matchDurationnorm_max  0.000000
# 484                killPlace_over_matchDurationnorm_max  0.000000
# 482                  killPlace_-_playersJoined_norm_max  0.000000
# 474                        kills_over_totalDistance_max  0.000000
# 481                       killPlace_-_playersJoined_max  0.000000
# 480                    killPlace_over_playersJoined_max  0.000000
# 479                     killPlace_over_maxPlaceNorm_max  0.000000
# 478                                    maxPlaceNorm_max  0.000000
# 477                                 damageDealtNorm_max  0.000000
# 476                                       killsNorm_max  0.000000
# 475                           kills_x_totalDistance_max  0.000000
# 453                       boosts_over_totalDistance_max  0.000000
# 452                 boosts_x_total_time_by_distance_max  0.000000
# 451              boosts_over_total_time_by_distance_max  0.000000
# 422                                       winPoints_max  0.000000
# 429                         walkDistance_over_heals_max  0.000000
# 428                     healthitems_norm_over_kills_max  0.000000
# 427                          healthitems_over_kills_max  0.000000
# 426                               heals_over_boosts_max  0.000000
# 425                                DBNOs_over_kills_max  0.000000
# 424                                  killStreakrate_max  0.000000
# 423                                    headshotrate_max  0.000000
# 421                                 weaponsAcquired_max  0.000000
# 431                         walkDistance_over_kills_max  0.000000
# 420                                    walkDistance_max  0.000000
# 419                                    swimDistance_max  0.000000
# 418                                    rideDistance_max  0.000000
# 417                                         revives_max  0.000000
# 416                                      rankPoints_max  0.000000
# 415                                        maxPlace_max  0.000000
# 414                                     longestKill_max  0.000000
# 430                            walkDistance_x_heals_max  0.000000
# 432                            walkDistance_x_kills_max  0.000000
# 450                       killPlace_x_totalDistance_max  0.000000
# 442                                   totalDistance_max  0.000000
# 449                    killPlace_over_totalDistance_max  0.000000
# 448              killPlace_x_total_time_by_distance_max  0.000000
# 447           killPlace_over_total_time_by_distance_max  0.000000
# 446                total_time_by_distance_x_weapons_max  0.000000
# 445             total_time_by_distance_over_weapons_max  0.000000
# 444                              distance_x_weapons_max  0.000000
# 443                           distance_over_weapons_max  0.000000
# 441                     total_time_by_distance_perc_max  0.000000
# 433                   walkDistance_over_healthitems_max  0.000000
# 440                    total_time_by_distance_place_max  0.000000
# 439                     total_time_by_distance_rank_max  0.000000
# 438                          total_time_by_distance_max  0.000000
# 437                        killPlace_over_numGroups_max  0.000000
# 436                         killPlace_over_maxPlace_max  0.000000
# 435                                           skill_max  0.000000
# 434                      walkDistance_x_healthitems_max  0.000000
# 1315                                     agg_match_size  0.000000
#
# [1316 rows x 2 columns]

# %%
m00 = RandomForestRegressor(n_jobs=-1, n_estimators=1, bootstrap=False, verbose=True)
# %time m00.fit(x_train, y_train)
print(mean_absolute_error(m00.predict(x_train), y_train))
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed: 180.0min finished
# CPU times: user 1h 19min 33s, sys: 1min 22s, total: 1h 20min 55s
# Wall time: 3h 1min 13s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   22.1s finished
# 1.2206105987112095e-05

# %%
t=m00.estimators_[0].tree_
dectree_max_depth(t)
# Out:
# 87

# %%
def rf_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}
                       ).sort_values('imp', ascending=False)
fi = rf_feat_importance(m00, x_train); display_all(fi)
fi.to_csv("tmp/20190109_fi_2.csv")
col = pd.Series(x_train.columns)
col.to_csv("tmp/20190109_col_2.csv")
fi_imp=fi[:359]
fi_imp.to_csv("tmp/20190109_fi_imp_2.csv")
# Out:
#                                                    cols           imp
# 159   total_items_acquired_norm_x_total_time_by_dist...  7.135310e-01
# 584               killPlace_over_matchDuration_max_rank  8.180896e-02
# 565   total_items_acquired_norm_+_total_time_by_dist...  7.512592e-02
# 486              killPlace_-_matchDurationnorm_rank_max  1.329984e-02
# 346   killPlace_over_total_time_by_distance_median_rank  1.053825e-02
# 539                     total_time_by_distance_max_rank  1.023182e-02
# 538                   killPlace_over_numGroups_max_rank  1.016219e-02
# 690              killPlace_-_matchDurationnorm_perc_min  3.909288e-03
# 580                killPlace_over_maxPlaceNorm_max_rank  3.757532e-03
# 775          kills_over_total_time_by_distance_min_rank  3.696052e-03
# 588        killPlace_-_matchDurationnorm_place_max_rank  3.432178e-03
# 1260           boosts_x_total_time_by_distance_sum_rank  2.984313e-03
# 439                     total_time_by_distance_rank_max  2.212715e-03
# 828                           killStreakrate_match_mean  2.137926e-03
# 585           killPlace_over_matchDurationnorm_max_rank  2.118947e-03
# 791         killPlace_-_matchDurationnorm_perc_min_rank  1.907140e-03
# 480                    killPlace_over_playersJoined_max  1.659830e-03
# 674               kills_over_total_time_by_distance_min  1.620418e-03
# 744                total_time_by_distance_perc_min_rank  1.610067e-03
# 779                                  killsNorm_min_rank  1.601664e-03
# 155   total_items_acquired_x_total_time_by_distance_...  1.383279e-03
# 512                                  killPlace_max_rank  1.318662e-03
# 437                        killPlace_over_numGroups_max  1.286827e-03
# 649           killPlace_over_total_time_by_distance_min  1.190474e-03
# 361   total_items_acquired_norm_x_total_time_by_dist...  1.122685e-03
# 582                  killPlace_-_playersJoined_max_rank  1.104671e-03
# 581               killPlace_over_playersJoined_max_rank  1.055637e-03
# 626                                  killStreakrate_min  1.053284e-03
# 540                total_time_by_distance_rank_max_rank  9.846275e-04
# 692                                   killPlacePerc_min  9.708536e-04
# 750      killPlace_over_total_time_by_distance_min_rank  9.646180e-04
# 381          killPlace_-_playersJoined_norm_median_rank  9.170970e-04
# 586              killPlace_-_matchDurationnorm_max_rank  7.615751e-04
# 537                    killPlace_over_maxPlace_max_rank  7.289015e-04
# 793                              killPlacePerc_min_rank  6.848807e-04
# 715                                      kills_min_rank  6.806035e-04
# 590         killPlace_-_matchDurationnorm_norm_max_rank  5.311308e-04
# 583             killPlace_-_playersJoined_norm_max_rank  5.204894e-04
# 727                             killStreakrate_min_rank  4.814296e-04
# 778                      kills_x_totalDistance_min_rank  4.585413e-04
# 1144                       killPlace_over_numGroups_sum  4.311661e-04
# 734                    walkDistance_over_kills_min_rank  4.027639e-04
# 776             kills_x_total_time_by_distance_min_rank  3.252938e-04
# 109                                     kills_mean_rank  3.183640e-04
# 20                                  killStreakrate_mean  3.039686e-04
# 716                                killStreaks_min_rank  2.955537e-04
# 48                 boosts_x_total_time_by_distance_mean  2.911683e-04
# 488              killPlace_-_matchDurationnorm_perc_max  2.682758e-04
# 587         killPlace_-_matchDurationnorm_rank_max_rank  2.520215e-04
# 717                                longestKill_min_rank  2.492275e-04
# 33                        killPlace_over_numGroups_mean  2.458134e-04
# 553            boosts_x_total_time_by_distance_max_rank  2.435989e-04
# 375                               killsNorm_median_rank  2.405830e-04
# 384           killPlace_-_matchDurationnorm_median_rank  2.396930e-04
# 541               total_time_by_distance_place_max_rank  2.323418e-04
# 436                         killPlace_over_maxPlace_max  1.963295e-04
# 735                       walkDistance_x_kills_min_rank  1.751667e-04
# 835                  walkDistance_over_kills_match_mean  1.736406e-04
# 311                                   kills_median_rank  1.691809e-04
# 173                                 killsNorm_mean_rank  1.615434e-04
# 1281            kills_x_total_time_by_distance_sum_rank  1.611342e-04
# 688              killPlace_-_matchDurationnorm_rank_min  1.605784e-04
# 817                              killStreaks_match_mean  1.572998e-04
# 72                                       killsNorm_mean  1.469126e-04
# 1246                    total_time_by_distance_sum_rank  1.415989e-04
# 144     killPlace_over_total_time_by_distance_mean_rank  1.377944e-04
# 633                         walkDistance_over_kills_min  1.322598e-04
# 752               killPlace_over_totalDistance_min_rank  1.313135e-04
# 32                         killPlace_over_maxPlace_mean  1.288804e-04
# 577                                  killsNorm_max_rank  1.287537e-04
# 521                               walkDistance_max_rank  1.274400e-04
# 639                        killPlace_over_numGroups_min  1.210524e-04
# 589         killPlace_-_matchDurationnorm_perc_max_rank  1.198630e-04
# 929                         killStreakrate_match_median  1.161174e-04
# 237                  total_time_by_distance_rank_median  1.127441e-04
# 1054       killPlace_x_total_time_by_distance_match_max  1.119339e-04
# 513                                      kills_max_rank  1.099666e-04
# 777                   kills_over_totalDistance_min_rank  1.088338e-04
# 525                             killStreakrate_max_rank  1.019171e-04
# 312                             killStreaks_median_rank  9.956019e-05
# 876        kills_over_total_time_by_distance_match_mean  9.508238e-05
# 490                                   killPlacePerc_max  9.453382e-05
# 682                    killPlace_over_playersJoined_min  9.173120e-05
# 274                                    killsNorm_median  8.744469e-05
# 1193             killPlace_-_matchDurationnorm_rank_sum  8.681604e-05
# 284           killPlace_-_matchDurationnorm_rank_median  8.647816e-05
# 476                                       killsNorm_max  8.232028e-05
# 816                                    kills_match_mean  8.228696e-05
# 563   total_items_acquired_norm_x_total_time_by_dist...  8.174756e-05
# 245        killPlace_over_total_time_by_distance_median  8.075491e-05
# 1284                                 killsNorm_sum_rank  8.015919e-05
# 161   total_items_acquired_norm_+_total_time_by_dist...  7.920250e-05
# 1220                                     kills_sum_rank  7.858461e-05
# 1037                  walkDistance_over_kills_match_max  7.747168e-05
# 827                             headshotrate_match_mean  7.538137e-05
# 731                healthitems_norm_over_kills_min_rank  7.327363e-05
# 1039            walkDistance_over_healthitems_match_max  7.253487e-05
# 372          kills_x_total_time_by_distance_median_rank  7.251483e-05
# 1020                              longestKill_match_max  7.195437e-05
# 1038                     walkDistance_x_kills_match_max  7.170746e-05
# 818                              longestKill_match_mean  7.149429e-05
# 1073  total_items_acquired_x_total_time_by_distance_...  7.105117e-05
# 1047              total_time_by_distance_perc_match_max  7.077127e-05
# 728                           DBNOs_over_kills_min_rank  7.054568e-05
# 387      killPlace_-_matchDurationnorm_perc_median_rank  6.926560e-05
# 1009                               damage1_match_median  6.906714e-05
# 1005        L3_over_total_time_by_distance_match_median  6.903809e-05
# 1051      total_time_by_distance_over_weapons_match_max  6.791046e-05
# 288                                killPlacePerc_median  6.784127e-05
# 1056                killPlace_x_totalDistance_match_max  6.749756e-05
# 514                                killStreaks_max_rank  6.731732e-05
# 331                    walkDistance_x_kills_median_rank  6.690988e-05
# 837            walkDistance_over_healthitems_match_mean  6.667842e-05
# 1035                  walkDistance_over_heals_match_max  6.657942e-05
# 235                     killPlace_over_numGroups_median  6.617845e-05
# 614                                           kills_min  6.600112e-05
# 548      killPlace_over_total_time_by_distance_max_rank  6.595517e-05
# 1079           kills_x_total_time_by_distance_match_max  6.568967e-05
# 880                                killsNorm_match_mean  6.568369e-05
# 1082                                killsNorm_match_max  6.563914e-05
# 638                         killPlace_over_maxPlace_min  6.452535e-05
# 948                  distance_over_weapons_match_median  6.342239e-05
# 1081                    kills_x_totalDistance_match_max  6.338404e-05
# 549         killPlace_x_total_time_by_distance_max_rank  6.338153e-05
# 1250                             totalDistance_sum_rank  6.188779e-05
# 730                     healthitems_over_kills_min_rank  6.188588e-05
# 1026                             walkDistance_match_max  6.185559e-05
# 1103              L2_x_total_time_by_distance_match_max  6.182856e-05
# 784                  killPlace_-_playersJoined_min_rank  6.177282e-05
# 833                  walkDistance_over_heals_match_mean  6.042335e-05
# 1232                            killStreakrate_sum_rank  6.033438e-05
# 1034              healthitems_norm_over_kills_match_max  6.023134e-05
# 110                               killStreaks_mean_rank  5.941259e-05
# 832              healthitems_norm_over_kills_match_mean  5.939857e-05
# 839                                    skill_match_mean  5.925190e-05
# 908                                  damage1_match_mean  5.923743e-05
# 904           L3_over_total_time_by_distance_match_mean  5.922953e-05
# 678                                       killsNorm_min  5.913941e-05
# 547           total_time_by_distance_x_weapons_max_rank  5.913427e-05
# 1049                    distance_over_weapons_match_max  5.907427e-05
# 1062                total_items_acquired_norm_match_max  5.888539e-05
# 1010                               damage2_match_median  5.836593e-05
# 7                                            kills_mean  5.819657e-05
# 878                 kills_over_totalDistance_match_mean  5.805091e-05
# 809                                  assists_match_mean  5.759384e-05
# 874                 heals_over_totalDistance_match_mean  5.726458e-05
# 1025                             swimDistance_match_max  5.720179e-05
# 1111                                  damage2_match_max  5.698192e-05
# 836                     walkDistance_x_kills_match_mean  5.682695e-05
# 543                              totalDistance_max_rank  5.654308e-05
# 1052         total_time_by_distance_x_weapons_match_max  5.650941e-05
# 348            killPlace_over_totalDistance_median_rank  5.643734e-05
# 912                            damageDealt_match_median  5.640398e-05
# 1099                                   points_match_max  5.610017e-05
# 1195             killPlace_-_matchDurationnorm_perc_sum  5.603201e-05
# 982                        damageDealtNorm_match_median  5.601836e-05
# 1105                       L2_x_totalDistance_match_max  5.572317e-05
# 479                     killPlace_over_maxPlaceNorm_max  5.550472e-05
# 811                              damageDealt_match_mean  5.540334e-05
# 823                             swimDistance_match_mean  5.435278e-05
# 643                     total_time_by_distance_perc_min  5.427397e-05
# 830                        heals_over_boosts_match_mean  5.394306e-05
# 1050                       distance_x_weapons_match_max  5.391240e-05
# 515                                longestKill_max_rank  5.360155e-05
# 708                                    assists_min_rank  5.315355e-05
# 1058          boosts_x_total_time_by_distance_match_max  5.262145e-05
# 1077                    heals_x_totalDistance_match_max  5.232750e-05
# 1183                                      killsNorm_sum  5.229336e-05
# 505                                         damage2_max  5.192668e-05
# 1007                 L3_over_totalDistance_match_median  5.164201e-05
# 909                                  damage2_match_mean  5.163758e-05
# 1110                                  damage1_match_max  5.162151e-05
# 1221                               killStreaks_sum_rank  5.150419e-05
# 1289                 killPlace_-_playersJoined_sum_rank  5.111995e-05
# 881                          damageDealtNorm_match_mean  5.073673e-05
# 813                            headshotKills_match_mean  5.063207e-05
# 831                   healthitems_over_kills_match_mean  5.032960e-05
# 855       boosts_over_total_time_by_distance_match_mean  5.013953e-05
# 86                                   killPlacePerc_mean  4.982095e-05
# 1185                                   maxPlaceNorm_sum  4.977545e-05
# 1315                                     agg_match_size  4.968686e-05
# 897                                   points_match_mean  4.936767e-05
# 1107              L3_x_total_time_by_distance_match_max  4.896359e-05
# 564   total_items_acquired_norm_+_total_time_by_dist...  4.858756e-05
# 10                                   matchDuration_mean  4.857485e-05
# 591                              killPlacePerc_max_rank  4.830421e-05
# 117                              walkDistance_mean_rank  4.788615e-05
# 872        heals_over_total_time_by_distance_match_mean  4.788552e-05
# 758                                   teamwork_min_rank  4.755592e-05
# 1074        heals_over_total_time_by_distance_match_max  4.749420e-05
# 825                          weaponsAcquired_match_mean  4.740892e-05
# 651                    killPlace_over_totalDistance_min  4.734861e-05
# 1083                          damageDealtNorm_match_max  4.719393e-05
# 1013                              damageDealt_match_max  4.714872e-05
# 1044                   total_time_by_distance_match_max  4.704003e-05
# 1222                               longestKill_sum_rank  4.698022e-05
# 1059                boosts_over_totalDistance_match_max  4.678695e-05
# 323                          killStreakrate_median_rank  4.667243e-05
# 185        killPlace_-_matchDurationnorm_perc_mean_rank  4.657684e-05
# 1101                    L1_over_totalDistance_match_max  4.652664e-05
# 1224                                rankPoints_sum_rank  4.637571e-05
# 1297        killPlace_-_matchDurationnorm_norm_sum_rank  4.616575e-05
# 851    killPlace_over_total_time_by_distance_match_mean  4.586930e-05
# 988           killPlace_over_matchDuration_match_median  4.582924e-05
# 229                      walkDistance_over_kills_median  4.578647e-05
# 895                                       L2_match_mean  4.568477e-05
# 810                                   boosts_match_mean  4.502318e-05
# 770   total_items_acquired_x_total_time_by_distance_...  4.499090e-05
# 1076                 heals_over_totalDistance_match_max  4.479378e-05
# 371       kills_over_total_time_by_distance_median_rank  4.454584e-05
# 345        total_time_by_distance_x_weapons_median_rank  4.439415e-05
# 1109                       L3_x_totalDistance_match_max  4.427650e-05
# 952   killPlace_over_total_time_by_distance_match_me...  4.412152e-05
# 852       killPlace_x_total_time_by_distance_match_mean  4.390351e-05
# 135                    total_time_by_distance_mean_rank  4.384568e-05
# 555                     boosts_x_totalDistance_max_rank  4.381134e-05
# 1254          total_time_by_distance_x_weapons_sum_rank  4.379049e-05
# 545                         distance_x_weapons_max_rank  4.362048e-05
# 899                    L1_over_totalDistance_match_mean  4.357408e-05
# 170            kills_x_total_time_by_distance_mean_rank  4.352399e-05
# 1283                     kills_x_totalDistance_sum_rank  4.328949e-05
# 857                boosts_over_totalDistance_match_mean  4.290202e-05
# 1078        kills_over_total_time_by_distance_match_max  4.288582e-05
# 917                                  kills_match_median  4.280756e-05
# 900           L2_over_total_time_by_distance_match_mean  4.262973e-05
# 795                                         L3_min_rank  4.262228e-05
# 278                 killPlace_over_playersJoined_median  4.238417e-05
# 374                   kills_x_totalDistance_median_rank  4.232411e-05
# 859                                 teamwork_match_mean  4.230707e-05
# 1057       boosts_over_total_time_by_distance_match_max  4.229850e-05
# 1036                     walkDistance_x_heals_match_max  4.216443e-05
# 172                     kills_x_totalDistance_mean_rank  4.207548e-05
# 681                     killPlace_over_maxPlaceNorm_min  4.201137e-05
# 616                                     longestKill_min  4.185862e-05
# 1098                                       L3_match_max  4.181338e-05
# 1080                 kills_over_totalDistance_match_max  4.168334e-05
# 507                                     boosts_max_rank  4.164914e-05
# 1060                   boosts_x_totalDistance_match_max  4.163390e-05
# 1228                              walkDistance_sum_rank  4.159634e-05
# 955              killPlace_x_totalDistance_match_median  4.157028e-05
# 319                            walkDistance_median_rank  4.140185e-05
# 343                      distance_x_weapons_median_rank  4.135384e-05
# 854                killPlace_x_totalDistance_match_mean  4.112690e-05
# 1184                                damageDealtNorm_sum  4.109847e-05
# 1300                                        L3_sum_rank  4.091078e-05
# 1100              L1_x_total_time_by_distance_match_max  4.086130e-05
# 1102           L2_over_total_time_by_distance_match_max  4.066087e-05
# 121                            killStreakrate_mean_rank  4.062571e-05
# 399          L3_over_total_time_by_distance_median_rank  4.055642e-05
# 1298                             killPlacePerc_sum_rank  4.032590e-05
# ...                                                 ...           ...
# 474                        kills_over_totalDistance_max  8.121586e-06
# 677                           kills_x_totalDistance_min  8.106962e-06
# 97                     L3_x_total_time_by_distance_mean  8.099455e-06
# 1131                                 killStreakrate_sum  8.096347e-06
# 301                           L3_x_totalDistance_median  8.066942e-06
# 1205                          L2_over_totalDistance_sum  8.031766e-06
# 1031                         DBNOs_over_kills_match_max  7.989728e-06
# 1129                                      winPoints_sum  7.983672e-06
# 625                                    headshotrate_min  7.971897e-06
# 485                   killPlace_-_matchDurationnorm_max  7.868703e-06
# 596                      L1_over_totalDistance_max_rank  7.863847e-06
# 69                  kills_x_total_time_by_distance_mean  7.857313e-06
# 191               L1_x_total_time_by_distance_mean_rank  7.837053e-06
# 181          killPlace_over_matchDurationnorm_mean_rank  7.772022e-06
# 994     killPlace_-_matchDurationnorm_norm_match_median  7.749540e-06
# 17                                 weaponsAcquired_mean  7.685780e-06
# 219                              weaponsAcquired_median  7.650848e-06
# 38                                   totalDistance_mean  7.617322e-06
# 99                              L3_x_totalDistance_mean  7.596051e-06
# 1194            killPlace_-_matchDurationnorm_place_sum  7.558890e-06
# 70                        kills_over_totalDistance_mean  7.553299e-06
# 232                   walkDistance_x_healthitems_median  7.480375e-06
# 700                           L2_over_totalDistance_min  7.453997e-06
# 269                        heals_x_totalDistance_median  7.442117e-06
# 888         killPlace_over_matchDurationnorm_match_mean  7.421925e-06
# 620                                    rideDistance_min  7.314539e-06
# 66                        heals_over_totalDistance_mean  7.261182e-06
# 1                                           boosts_mean  7.129070e-06
# 83             killPlace_-_matchDurationnorm_place_mean  7.122590e-06
# 980                  kills_x_totalDistance_match_median  7.121103e-06
# 290                                           L3_median  7.057380e-06
# 469                  heals_x_total_time_by_distance_max  6.995157e-06
# 258   total_items_acquired_+_total_time_by_distance_...  6.990706e-06
# 990          killPlace_-_matchDurationnorm_match_median  6.977743e-06
# 204                                       boosts_median  6.976628e-06
# 673                           heals_x_totalDistance_min  6.970707e-06
# 268                     heals_over_totalDistance_median  6.963235e-06
# 59    total_items_acquired_norm_+_total_time_by_dist...  6.872774e-06
# 228                         walkDistance_x_heals_median  6.796301e-06
# 108                                 killPlace_mean_rank  6.769542e-06
# 408                                           DBNOs_max  6.731093e-06
# 415                                        maxPlace_max  6.720028e-06
# 426                               heals_over_boosts_max  6.703273e-06
# 60    total_items_acquired_norm_+_total_time_by_dist...  6.678657e-06
# 283                killPlace_-_matchDurationnorm_median  6.677482e-06
# 1203                 L2_over_total_time_by_distance_sum  6.663396e-06
# 377                            maxPlaceNorm_median_rank  6.660641e-06
# 240                                totalDistance_median  6.582606e-06
# 182             killPlace_-_matchDurationnorm_mean_rank  6.563535e-06
# 1137                           walkDistance_x_heals_sum  6.531323e-06
# 134                  killPlace_over_numGroups_mean_rank  6.484092e-06
# 1115                                          DBNOs_sum  6.397628e-06
# 95                              L2_x_totalDistance_mean  6.394025e-06
# 87                                              L2_mean  6.374656e-06
# 1132                               DBNOs_over_kills_sum  6.251463e-06
# 680                                    maxPlaceNorm_min  6.208703e-06
# 23                          healthitems_over_kills_mean  6.202954e-06
# 471                           heals_x_totalDistance_max  6.173012e-06
# 21                                DBNOs_over_kills_mean  6.107245e-06
# 56    total_items_acquired_+_total_time_by_distance_...  6.106921e-06
# 1118                                      killPlace_sum  6.071533e-06
# 628                               heals_over_boosts_min  6.061984e-06
# 176               killPlace_over_maxPlaceNorm_mean_rank  6.056309e-06
# 175                              maxPlaceNorm_mean_rank  6.049272e-06
# 24                     healthitems_norm_over_kills_mean  6.049062e-06
# 224                            heals_over_boosts_median  6.047954e-06
# 632                            walkDistance_x_heals_min  6.039149e-06
# 740                   killPlace_over_numGroups_min_rank  5.975773e-06
# 184       killPlace_-_matchDurationnorm_place_mean_rank  5.888225e-06
# 74                                    maxPlaceNorm_mean  5.851171e-06
# 0                                          assists_mean  5.833565e-06
# 889            killPlace_-_matchDurationnorm_match_mean  5.805529e-06
# 1021                                 maxPlace_match_max  5.792788e-06
# 81                   killPlace_-_matchDurationnorm_mean  5.761637e-06
# 579                               maxPlaceNorm_max_rank  5.748840e-06
# 1176                 heals_x_total_time_by_distance_sum  5.719809e-06
# 213                                     maxPlace_median  5.714805e-06
# 882                             maxPlaceNorm_match_mean  5.709806e-06
# 1091            killPlace_-_matchDurationnorm_match_max  5.600728e-06
# 893       killPlace_-_matchDurationnorm_norm_match_mean  5.588811e-06
# 67                           heals_x_totalDistance_mean  5.399959e-06
# 694                                              L3_min  5.394059e-06
# 88                                              L3_mean  5.382981e-06
# 1125                                   rideDistance_sum  5.376160e-06
# 1023                                  revives_match_max  5.360556e-06
# 18                                       winPoints_mean  5.357309e-06
# 267               heals_x_total_time_by_distance_median  5.329864e-06
# 386     killPlace_-_matchDurationnorm_place_median_rank  5.298482e-06
# 65                  heals_x_total_time_by_distance_mean  5.281643e-06
# 492                                              L3_max  5.254962e-06
# 11                                        maxPlace_mean  5.248143e-06
# 1089             killPlace_over_matchDuration_match_max  5.201225e-06
# 19                                    headshotrate_mean  5.163606e-06
# 221                                 headshotrate_median  5.155747e-06
# 112                                  maxPlace_mean_rank  5.155148e-06
# 937                   walkDistance_x_kills_match_median  5.127021e-06
# 1046             total_time_by_distance_place_match_max  5.116656e-06
# 494                     L1_x_total_time_by_distance_max  5.099615e-06
# 887             killPlace_over_matchDuration_match_mean  5.092596e-06
# 983                           maxPlaceNorm_match_median  5.084604e-06
# 792         killPlace_-_matchDurationnorm_norm_min_rank  5.038742e-06
# 210                                        kills_median  4.995293e-06
# 478                                    maxPlaceNorm_max  4.993283e-06
# 973      heals_over_total_time_by_distance_match_median  4.992382e-06
# 617                                        maxPlace_min  4.971139e-06
# 1134                         healthitems_over_kills_sum  4.961596e-06
# 934                walkDistance_over_heals_match_median  4.934236e-06
# 421                                 weaponsAcquired_max  4.912469e-06
# 425                                DBNOs_over_kills_max  4.880656e-06
# 310                               killPlace_median_rank  4.816443e-06
# 1084                             maxPlaceNorm_match_max  4.795956e-06
# 623                                 weaponsAcquired_min  4.677610e-06
# 5                                            heals_mean  4.641836e-06
# 621                                    swimDistance_min  4.640835e-06
# 178                 killPlace_-_playersJoined_mean_rank  4.637362e-06
# 15                                    swimDistance_mean  4.589856e-06
# 222                               killStreakrate_median  4.582524e-06
# 1130                                   headshotrate_sum  4.510951e-06
# 971   total_items_acquired_x_total_time_by_distance_...  4.377586e-06
# 418                                    rideDistance_max  4.272767e-06
# 819                                 maxPlace_match_mean  4.270051e-06
# 423                                    headshotrate_max  4.244879e-06
# 1116                                  headshotKills_sum  4.151734e-06
# 1112                                        assists_sum  4.117053e-06
# 292                  L1_x_total_time_by_distance_median  4.087836e-06
# 314                                maxPlace_median_rank  3.893192e-06
# 671                  heals_x_total_time_by_distance_min  3.850916e-06
# 944            total_time_by_distance_rank_match_median  3.802332e-06
# 956     boosts_over_total_time_by_distance_match_median  3.783600e-06
# 886           killPlace_-_playersJoined_norm_match_mean  3.735923e-06
# 1126                                   swimDistance_sum  3.731014e-06
# 427                          healthitems_over_kills_max  3.727453e-06
# 419                                    swimDistance_max  3.643246e-06
# 1117                                          heals_sum  3.628098e-06
# 926                        weaponsAcquired_match_median  3.624946e-06
# 933            healthitems_norm_over_kills_match_median  3.603622e-06
# 91                           L1_over_totalDistance_mean  3.586882e-06
# 14                                    rideDistance_mean  3.565499e-06
# 276                                 maxPlaceNorm_median  3.541815e-06
# 1201                    L1_x_total_time_by_distance_sum  3.520003e-06
# 225                       healthitems_over_kills_median  3.437679e-06
# 495                           L1_over_totalDistance_max  3.369913e-06
# 405                                         assists_max  3.320644e-06
# 928                           headshotrate_match_median  3.244491e-06
# 1120                                    killStreaks_sum  3.207477e-06
# 987         killPlace_-_playersJoined_norm_match_median  3.201835e-06
# 945           total_time_by_distance_place_match_median  3.094147e-06
# 869   total_items_acquired_x_total_time_by_distance_...  3.053341e-06
# 1088           killPlace_-_playersJoined_norm_match_max  2.993256e-06
# 1162                                       teamwork_sum  2.911066e-06
# 90                     L1_x_total_time_by_distance_mean  2.849087e-06
# 1202                          L1_over_totalDistance_sum  2.822596e-06
# 410                                           heals_max  2.783162e-06
# 1142                                          skill_sum  2.782456e-06
# 51                                        teamwork_mean  2.714724e-06
# 216                                 rideDistance_median  2.702169e-06
# 206                                        DBNOs_median  2.666684e-06
# 781                               maxPlaceNorm_min_rank  2.661725e-06
# 516                                   maxPlace_max_rank  2.611569e-06
# 608                                          boosts_min  2.611278e-06
# 629                          healthitems_over_kills_min  2.590247e-06
# 985           killPlace_over_playersJoined_match_median  2.584695e-06
# 991     killPlace_-_matchDurationnorm_rank_match_median  2.554065e-06
# 870   total_items_acquired_x_total_time_by_distance_...  2.534103e-06
# 1017                                killPlace_match_max  2.505961e-06
# 455                                        teamwork_max  2.444811e-06
# 932                 healthitems_over_kills_match_median  2.408287e-06
# 986              killPlace_-_playersJoined_match_median  2.394993e-06
# 208                                        heals_median  2.343151e-06
# 891      killPlace_-_matchDurationnorm_place_match_mean  2.289909e-06
# 913                                  DBNOs_match_median  2.286639e-06
# 923                           rideDistance_match_median  2.281942e-06
# 31                                           skill_mean  2.225486e-06
# 957        boosts_x_total_time_by_distance_match_median  2.208743e-06
# 612                                           heals_min  2.202558e-06
# 844             total_time_by_distance_place_match_mean  2.157442e-06
# 970   total_items_acquired_x_total_time_by_distance_...  2.144317e-06
# 13                                         revives_mean  2.136590e-06
# 885                killPlace_-_playersJoined_match_mean  2.124415e-06
# 1072  total_items_acquired_x_total_time_by_distance_...  2.111182e-06
# 884             killPlace_over_playersJoined_match_mean  2.054703e-06
# 975               heals_over_totalDistance_match_median  2.045699e-06
# 815                                killPlace_match_mean  2.040415e-06
# 890       killPlace_-_matchDurationnorm_rank_match_mean  2.040022e-06
# 4                                    headshotKills_mean  2.038031e-06
# 253                                     teamwork_median  1.971755e-06
# 1093      killPlace_-_matchDurationnorm_place_match_max  1.969442e-06
# 491                                              L2_max  1.960657e-06
# 916                              killPlace_match_median  1.914094e-06
# 992    killPlace_-_matchDurationnorm_place_match_median  1.912966e-06
# 1004                    L2_x_totalDistance_match_median  1.841949e-06
# 217                                 swimDistance_median  1.841116e-06
# 1124                                        revives_sum  1.788131e-06
# 293                        L1_over_totalDistance_median  1.761835e-06
# 843              total_time_by_distance_rank_match_mean  1.743446e-06
# 289                                           L2_median  1.702287e-06
# 203                                      assists_median  1.635421e-06
# 959                 boosts_x_totalDistance_match_median  1.615346e-06
# 215                                      revives_median  1.589112e-06
# 976                  heals_x_totalDistance_match_median  1.444768e-06
# 207                                headshotKills_median  1.404664e-06
# 211                                  killStreaks_median  1.368737e-06
# 610                                           DBNOs_min  1.366429e-06
# 413                                     killStreaks_max  1.272918e-06
# 693                                              L2_min  1.221292e-06
# 233                                        skill_median  9.911386e-07
# 417                                         revives_max  9.250624e-07
# 697                           L1_over_totalDistance_min  8.717665e-07
# 935                   walkDistance_x_heals_match_median  8.441334e-07
# 409                                   headshotKills_max  8.091495e-07
# 974         heals_x_total_time_by_distance_match_median  7.836986e-07
# 657                                        teamwork_min  7.390049e-07
# 424                                  killStreakrate_max  6.964155e-07
# 946            total_time_by_distance_perc_match_median  6.713934e-07
# 607                                         assists_min  5.198023e-07
# 435                                           skill_max  5.162928e-07
# 911                                 boosts_match_median  3.979246e-07
# 637                                           skill_min  3.958751e-07
# 931                      heals_over_boosts_match_median  3.767784e-07
# 615                                     killStreaks_min  3.206070e-07
# 696                     L1_x_total_time_by_distance_min  3.174943e-07
# 918                            killStreaks_match_median  3.024659e-07
# 1001        L2_over_total_time_by_distance_match_median  3.014114e-07
# 915                                  heals_match_median  2.723687e-07
# 619                                         revives_min  2.363587e-07
# 910                                assists_match_median  1.888848e-07
# 611                                   headshotKills_min  1.888415e-07
# 1045              total_time_by_distance_rank_match_max  1.459217e-07
# 960                               teamwork_match_median  7.879677e-08
# 930                       DBNOs_over_kills_match_median  5.990971e-08
# 996                                     L2_match_median  2.088332e-08
# 972   total_items_acquired_x_total_time_by_distance_...  1.986715e-08
# 894                            killPlacePerc_match_mean  5.217318e-10
# 1086             killPlace_over_playersJoined_match_max  2.735522e-10
# 1087                killPlace_-_playersJoined_match_max  8.900117e-11
# 995                          killPlacePerc_match_median  4.697685e-12
# 1071  total_items_acquired_x_total_time_by_distance_...  0.000000e+00
# 892       killPlace_-_matchDurationnorm_perc_match_mean  0.000000e+00
# 1096                            killPlacePerc_match_max  0.000000e+00
# 1094       killPlace_-_matchDurationnorm_perc_match_max  0.000000e+00
# 1092       killPlace_-_matchDurationnorm_rank_match_max  0.000000e+00
# 845              total_time_by_distance_perc_match_mean  0.000000e+00
# 922                                revives_match_median  0.000000e+00
# 1030                           killStreakrate_match_max  0.000000e+00
# 1000                 L1_over_totalDistance_match_median  0.000000e+00
# 999            L1_x_total_time_by_distance_match_median  0.000000e+00
# 993     killPlace_-_matchDurationnorm_perc_match_median  0.000000e+00
# 940                                  skill_match_median  0.000000e+00
# 924                           swimDistance_match_median  0.000000e+00
# 871   total_items_acquired_x_total_time_by_distance_...  0.000000e+00
#
# [1316 rows x 2 columns]
